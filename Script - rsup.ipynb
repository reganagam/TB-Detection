# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pathlib
import os
import seaborn as sns
#Dataset Directory
training_dir = "Dataset/Dataset RSUP/Training"
validation_dir = "Dataset/Dataset RSUP/Validation"

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
#Image Normalization and Image Augmentation
train_datagen = ImageDataGenerator(
      rescale=1./255,
      width_shift_range=0.1,
      height_shift_range=0.1,
      horizontal_flip=True,
      rotation_range=0.1,
      fill_mode='nearest'
    )

validation_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(training_dir,
                                                    batch_size=32,
                                                    class_mode='categorical',
                                                    target_size=(150, 150))

validation_generator = validation_datagen.flow_from_directory(validation_dir,
                                                              batch_size=32,
                                                              class_mode  = 'categorical',
                                                              target_size = (150, 150))

train_generator.class_indices
# Out:
# Found 648 images belonging to 3 classes.
# Found 159 images belonging to 3 classes.
# {'Covid-19': 0, 'Normal': 1, 'Tuberkulosis': 2}

# %% [markdown]
# # **Training first Model with my own architectur (Model C)**

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(150,150,3)),
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(3, activation='softmax')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 148, 148, 32)      896
#
#  conv2d_1 (Conv2D)           (None, 146, 146, 64)      18496
#
#  max_pooling2d (MaxPooling2D  (None, 73, 73, 64)       0
#  )
#
#  dropout (Dropout)           (None, 73, 73, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 71, 71, 64)        36928
#
#  max_pooling2d_1 (MaxPooling  (None, 35, 35, 64)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 35, 35, 64)        0
#
#  conv2d_3 (Conv2D)           (None, 33, 33, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 16, 16, 128)      0
#  2D)
#
#  dropout_2 (Dropout)         (None, 16, 16, 128)       0
#
#  flatten (Flatten)           (None, 32768)             0
#
#  dense (Dense)               (None, 64)                2097216
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 2,227,587
# Trainable params: 2,227,587
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Learning Rate Scheduler
from tensorflow.keras.optimizers.schedules import PolynomialDecay

num_epochs = 100
num_train_steps = (train_generator.samples // 32) * num_epochs
lr_scheduler = PolynomialDecay(
    initial_learning_rate=5e-5, end_learning_rate=0.0,
    decay_steps=num_train_steps
)

# %%
from tensorflow.keras.optimizers import Adam
model.compile(optimizer=Adam(learning_rate=lr_scheduler), loss='categorical_crossentropy', metrics=['accuracy'])

# Callbacks (optional)
# class MyCallback(tf.keras.callbacks.Callback):
#   def on_epoch_end(self, epoch, logs={}):
#     if (logs.get('accuracy')>0.95 and logs.get('val_accuracy')>0.95):
#       print('Good enough accuracy so cancelling training!')
#       self.model.stop_training = True

# callback = MyCallback()

#Training proccess
history = model.fit(
    train_generator,
    steps_per_epoch = train_generator.samples // 32,
    epochs = 100,
    validation_data = validation_generator,
    validation_steps = validation_generator.samples // 32,
    verbose = 2
    # callbacks=[callback]
)
# Out:
# Epoch 1/100
# 20/20 - 24s - loss: 1.1203 - accuracy: 0.3312 - val_loss: 1.0970 - val_accuracy: 0.3281 - 24s/epoch - 1s/step
# Epoch 2/100
# 20/20 - 6s - loss: 1.1051 - accuracy: 0.3604 - val_loss: 1.0966 - val_accuracy: 0.3750 - 6s/epoch - 307ms/step
# Epoch 3/100
# 20/20 - 6s - loss: 1.0916 - accuracy: 0.3945 - val_loss: 1.0969 - val_accuracy: 0.3828 - 6s/epoch - 305ms/step
# Epoch 4/100
# 20/20 - 6s - loss: 1.0953 - accuracy: 0.3506 - val_loss: 1.0952 - val_accuracy: 0.3672 - 6s/epoch - 308ms/step
# Epoch 5/100
# 20/20 - 7s - loss: 1.0890 - accuracy: 0.3815 - val_loss: 1.0933 - val_accuracy: 0.3828 - 7s/epoch - 361ms/step
# Epoch 6/100
# 20/20 - 7s - loss: 1.0826 - accuracy: 0.4123 - val_loss: 1.0905 - val_accuracy: 0.4531 - 7s/epoch - 367ms/step
# Epoch 7/100
# 20/20 - 7s - loss: 1.0884 - accuracy: 0.3896 - val_loss: 1.0897 - val_accuracy: 0.3828 - 7s/epoch - 363ms/step
# Epoch 8/100
# 20/20 - 7s - loss: 1.0819 - accuracy: 0.3896 - val_loss: 1.0894 - val_accuracy: 0.4375 - 7s/epoch - 343ms/step
# Epoch 9/100
# 20/20 - 7s - loss: 1.0803 - accuracy: 0.3977 - val_loss: 1.0898 - val_accuracy: 0.3516 - 7s/epoch - 340ms/step
# Epoch 10/100
# 20/20 - 6s - loss: 1.0823 - accuracy: 0.3961 - val_loss: 1.0882 - val_accuracy: 0.4297 - 6s/epoch - 316ms/step
# Epoch 11/100
# 20/20 - 6s - loss: 1.0868 - accuracy: 0.3896 - val_loss: 1.0839 - val_accuracy: 0.4375 - 6s/epoch - 309ms/step
# Epoch 12/100
# 20/20 - 6s - loss: 1.0804 - accuracy: 0.3945 - val_loss: 1.0878 - val_accuracy: 0.4688 - 6s/epoch - 304ms/step
# Epoch 13/100
# 20/20 - 6s - loss: 1.0757 - accuracy: 0.4058 - val_loss: 1.0807 - val_accuracy: 0.4766 - 6s/epoch - 309ms/step
# Epoch 14/100
# 20/20 - 7s - loss: 1.0673 - accuracy: 0.4188 - val_loss: 1.0751 - val_accuracy: 0.5312 - 7s/epoch - 358ms/step
# Epoch 15/100
# 20/20 - 7s - loss: 1.0634 - accuracy: 0.4383 - val_loss: 1.0759 - val_accuracy: 0.4375 - 7s/epoch - 327ms/step
# Epoch 16/100
# 20/20 - 6s - loss: 1.0650 - accuracy: 0.4318 - val_loss: 1.0723 - val_accuracy: 0.4297 - 6s/epoch - 312ms/step
# Epoch 17/100
# 20/20 - 6s - loss: 1.0829 - accuracy: 0.3864 - val_loss: 1.0802 - val_accuracy: 0.4609 - 6s/epoch - 310ms/step
# Epoch 18/100
# 20/20 - 6s - loss: 1.0698 - accuracy: 0.4302 - val_loss: 1.0757 - val_accuracy: 0.4375 - 6s/epoch - 311ms/step
# Epoch 19/100
# 20/20 - 6s - loss: 1.0701 - accuracy: 0.4334 - val_loss: 1.0726 - val_accuracy: 0.4688 - 6s/epoch - 313ms/step
# Epoch 20/100
# 20/20 - 6s - loss: 1.0897 - accuracy: 0.3490 - val_loss: 1.0780 - val_accuracy: 0.4609 - 6s/epoch - 310ms/step
# Epoch 21/100
# 20/20 - 6s - loss: 1.0659 - accuracy: 0.4269 - val_loss: 1.0783 - val_accuracy: 0.4688 - 6s/epoch - 312ms/step
# Epoch 22/100
# 20/20 - 6s - loss: 1.0712 - accuracy: 0.3994 - val_loss: 1.0797 - val_accuracy: 0.4062 - 6s/epoch - 310ms/step
# Epoch 23/100
# 20/20 - 7s - loss: 1.0622 - accuracy: 0.4286 - val_loss: 1.0642 - val_accuracy: 0.4922 - 7s/epoch - 339ms/step
# Epoch 24/100
# 20/20 - 7s - loss: 1.0651 - accuracy: 0.4367 - val_loss: 1.0615 - val_accuracy: 0.5312 - 7s/epoch - 373ms/step
# Epoch 25/100
# 20/20 - 8s - loss: 1.0442 - accuracy: 0.4205 - val_loss: 1.0677 - val_accuracy: 0.4609 - 8s/epoch - 377ms/step
# Epoch 26/100
# 20/20 - 7s - loss: 1.0603 - accuracy: 0.4253 - val_loss: 1.0614 - val_accuracy: 0.5312 - 7s/epoch - 374ms/step
# Epoch 27/100
# 20/20 - 7s - loss: 1.0435 - accuracy: 0.4302 - val_loss: 1.0534 - val_accuracy: 0.5703 - 7s/epoch - 331ms/step
# Epoch 28/100
# 20/20 - 7s - loss: 1.0513 - accuracy: 0.4416 - val_loss: 1.0558 - val_accuracy: 0.5156 - 7s/epoch - 331ms/step
# Epoch 29/100
# 20/20 - 6s - loss: 1.0479 - accuracy: 0.4594 - val_loss: 1.0617 - val_accuracy: 0.4688 - 6s/epoch - 311ms/step
# Epoch 30/100
# 20/20 - 6s - loss: 1.0502 - accuracy: 0.4416 - val_loss: 1.0627 - val_accuracy: 0.4922 - 6s/epoch - 323ms/step
# Epoch 31/100
# 20/20 - 6s - loss: 1.0657 - accuracy: 0.4448 - val_loss: 1.0509 - val_accuracy: 0.4766 - 6s/epoch - 312ms/step
# Epoch 32/100
# 20/20 - 7s - loss: 1.0463 - accuracy: 0.4513 - val_loss: 1.0590 - val_accuracy: 0.4766 - 7s/epoch - 346ms/step
# Epoch 33/100
# 20/20 - 7s - loss: 1.0629 - accuracy: 0.4529 - val_loss: 1.0605 - val_accuracy: 0.5156 - 7s/epoch - 332ms/step
# Epoch 34/100
# 20/20 - 6s - loss: 1.0469 - accuracy: 0.4562 - val_loss: 1.0585 - val_accuracy: 0.5234 - 6s/epoch - 319ms/step
# Epoch 35/100
# 20/20 - 6s - loss: 1.0427 - accuracy: 0.4594 - val_loss: 1.0450 - val_accuracy: 0.5234 - 6s/epoch - 312ms/step
# Epoch 36/100
# 20/20 - 6s - loss: 1.0301 - accuracy: 0.4675 - val_loss: 1.0524 - val_accuracy: 0.4688 - 6s/epoch - 305ms/step
# Epoch 37/100
# 20/20 - 6s - loss: 1.0665 - accuracy: 0.4416 - val_loss: 1.0540 - val_accuracy: 0.4531 - 6s/epoch - 319ms/step
# Epoch 38/100
# 20/20 - 6s - loss: 1.0494 - accuracy: 0.4383 - val_loss: 1.0532 - val_accuracy: 0.4531 - 6s/epoch - 310ms/step
# Epoch 39/100
# 20/20 - 7s - loss: 1.0447 - accuracy: 0.4497 - val_loss: 1.0466 - val_accuracy: 0.5312 - 7s/epoch - 340ms/step
# Epoch 40/100
# 20/20 - 6s - loss: 1.0472 - accuracy: 0.4351 - val_loss: 1.0498 - val_accuracy: 0.4922 - 6s/epoch - 313ms/step
# Epoch 41/100
# 20/20 - 7s - loss: 1.0420 - accuracy: 0.4351 - val_loss: 1.0497 - val_accuracy: 0.5234 - 7s/epoch - 333ms/step
# Epoch 42/100
# 20/20 - 7s - loss: 1.0458 - accuracy: 0.4464 - val_loss: 1.0488 - val_accuracy: 0.5078 - 7s/epoch - 375ms/step
# Epoch 43/100
# 20/20 - 7s - loss: 1.0589 - accuracy: 0.4481 - val_loss: 1.0484 - val_accuracy: 0.5000 - 7s/epoch - 373ms/step
# Epoch 44/100
# 20/20 - 10s - loss: 1.0491 - accuracy: 0.4675 - val_loss: 1.0565 - val_accuracy: 0.4922 - 10s/epoch - 475ms/step
# Epoch 45/100
# 20/20 - 6s - loss: 1.0295 - accuracy: 0.4497 - val_loss: 1.0456 - val_accuracy: 0.3984 - 6s/epoch - 312ms/step
# Epoch 46/100
# 20/20 - 7s - loss: 1.0494 - accuracy: 0.4253 - val_loss: 1.0408 - val_accuracy: 0.5312 - 7s/epoch - 338ms/step
# Epoch 47/100
# 20/20 - 6s - loss: 1.0393 - accuracy: 0.4383 - val_loss: 1.0438 - val_accuracy: 0.4922 - 6s/epoch - 319ms/step
# Epoch 48/100
# 20/20 - 7s - loss: 1.0368 - accuracy: 0.4578 - val_loss: 1.0445 - val_accuracy: 0.5078 - 7s/epoch - 345ms/step
# Epoch 49/100
# 20/20 - 7s - loss: 1.0483 - accuracy: 0.4318 - val_loss: 1.0466 - val_accuracy: 0.5078 - 7s/epoch - 327ms/step
# Epoch 50/100
# 20/20 - 8s - loss: 1.0409 - accuracy: 0.4334 - val_loss: 1.0581 - val_accuracy: 0.4141 - 8s/epoch - 384ms/step
# Epoch 51/100
# 20/20 - 8s - loss: 1.0338 - accuracy: 0.4383 - val_loss: 1.0413 - val_accuracy: 0.4766 - 8s/epoch - 377ms/step
# Epoch 52/100
# 20/20 - 7s - loss: 1.0346 - accuracy: 0.4481 - val_loss: 1.0419 - val_accuracy: 0.4766 - 7s/epoch - 371ms/step
# Epoch 53/100
# 20/20 - 7s - loss: 1.0431 - accuracy: 0.4497 - val_loss: 1.0401 - val_accuracy: 0.4766 - 7s/epoch - 341ms/step
# Epoch 54/100
# 20/20 - 7s - loss: 1.0389 - accuracy: 0.4659 - val_loss: 1.0491 - val_accuracy: 0.4766 - 7s/epoch - 327ms/step
# Epoch 55/100
# 20/20 - 6s - loss: 1.0364 - accuracy: 0.4643 - val_loss: 1.0449 - val_accuracy: 0.5156 - 6s/epoch - 316ms/step
# Epoch 56/100
# 20/20 - 6s - loss: 1.0085 - accuracy: 0.4724 - val_loss: 1.0347 - val_accuracy: 0.4688 - 6s/epoch - 310ms/step
# Epoch 57/100
# 20/20 - 6s - loss: 1.0208 - accuracy: 0.4432 - val_loss: 1.0430 - val_accuracy: 0.4766 - 6s/epoch - 318ms/step
# Epoch 58/100
# 20/20 - 7s - loss: 1.0171 - accuracy: 0.4734 - val_loss: 1.0437 - val_accuracy: 0.4922 - 7s/epoch - 335ms/step
# Epoch 59/100
# 20/20 - 7s - loss: 1.0432 - accuracy: 0.4756 - val_loss: 1.0340 - val_accuracy: 0.5391 - 7s/epoch - 350ms/step
# Epoch 60/100
# 20/20 - 7s - loss: 1.0311 - accuracy: 0.4610 - val_loss: 1.0445 - val_accuracy: 0.5000 - 7s/epoch - 340ms/step
# Epoch 61/100
# 20/20 - 6s - loss: 1.0316 - accuracy: 0.4594 - val_loss: 1.0396 - val_accuracy: 0.5156 - 6s/epoch - 305ms/step
# Epoch 62/100
# 20/20 - 6s - loss: 1.0486 - accuracy: 0.4594 - val_loss: 1.0376 - val_accuracy: 0.4688 - 6s/epoch - 319ms/step
# Epoch 63/100
# 20/20 - 7s - loss: 1.0329 - accuracy: 0.4318 - val_loss: 1.0357 - val_accuracy: 0.5000 - 7s/epoch - 328ms/step
# Epoch 64/100
# 20/20 - 6s - loss: 1.0323 - accuracy: 0.4659 - val_loss: 1.0374 - val_accuracy: 0.5156 - 6s/epoch - 314ms/step
# Epoch 65/100
# 20/20 - 6s - loss: 1.0316 - accuracy: 0.4708 - val_loss: 1.0333 - val_accuracy: 0.5078 - 6s/epoch - 319ms/step
# Epoch 66/100
# 20/20 - 7s - loss: 1.0096 - accuracy: 0.4903 - val_loss: 1.0446 - val_accuracy: 0.5000 - 7s/epoch - 351ms/step
# Epoch 67/100
# 20/20 - 6s - loss: 1.0346 - accuracy: 0.4545 - val_loss: 1.0310 - val_accuracy: 0.4766 - 6s/epoch - 315ms/step
# Epoch 68/100
# 20/20 - 8s - loss: 1.0385 - accuracy: 0.4334 - val_loss: 1.0347 - val_accuracy: 0.5312 - 8s/epoch - 397ms/step
# Epoch 69/100
# 20/20 - 8s - loss: 1.0223 - accuracy: 0.4838 - val_loss: 1.0424 - val_accuracy: 0.5000 - 8s/epoch - 409ms/step
# Epoch 70/100
# 20/20 - 7s - loss: 1.0289 - accuracy: 0.4756 - val_loss: 1.0428 - val_accuracy: 0.4688 - 7s/epoch - 370ms/step
# Epoch 71/100
# 20/20 - 7s - loss: 1.0284 - accuracy: 0.4854 - val_loss: 1.0370 - val_accuracy: 0.4844 - 7s/epoch - 327ms/step
# Epoch 72/100
# 20/20 - 6s - loss: 1.0346 - accuracy: 0.4627 - val_loss: 1.0292 - val_accuracy: 0.5000 - 6s/epoch - 312ms/step
# Epoch 73/100
# 20/20 - 7s - loss: 1.0099 - accuracy: 0.4903 - val_loss: 1.0345 - val_accuracy: 0.4688 - 7s/epoch - 327ms/step
# Epoch 74/100
# 20/20 - 7s - loss: 1.0188 - accuracy: 0.4756 - val_loss: 1.0400 - val_accuracy: 0.4922 - 7s/epoch - 344ms/step
# Epoch 75/100
# 20/20 - 7s - loss: 1.0248 - accuracy: 0.4805 - val_loss: 1.0419 - val_accuracy: 0.5000 - 7s/epoch - 344ms/step
# Epoch 76/100
# 20/20 - 7s - loss: 1.0212 - accuracy: 0.4756 - val_loss: 1.0424 - val_accuracy: 0.4844 - 7s/epoch - 345ms/step
# Epoch 77/100
# 20/20 - 7s - loss: 1.0262 - accuracy: 0.4692 - val_loss: 1.0289 - val_accuracy: 0.5234 - 7s/epoch - 340ms/step
# Epoch 78/100
# 20/20 - 6s - loss: 1.0156 - accuracy: 0.4594 - val_loss: 1.0229 - val_accuracy: 0.5703 - 6s/epoch - 322ms/step
# Epoch 79/100
# 20/20 - 6s - loss: 1.0183 - accuracy: 0.4562 - val_loss: 1.0414 - val_accuracy: 0.4688 - 6s/epoch - 321ms/step
# Epoch 80/100
# 20/20 - 6s - loss: 1.0120 - accuracy: 0.4903 - val_loss: 1.0427 - val_accuracy: 0.4688 - 6s/epoch - 315ms/step
# Epoch 81/100
# 20/20 - 6s - loss: 1.0167 - accuracy: 0.4724 - val_loss: 1.0260 - val_accuracy: 0.5156 - 6s/epoch - 321ms/step
# Epoch 82/100
# 20/20 - 7s - loss: 1.0226 - accuracy: 0.4708 - val_loss: 1.0325 - val_accuracy: 0.5000 - 7s/epoch - 333ms/step
# Epoch 83/100
# 20/20 - 6s - loss: 1.0163 - accuracy: 0.4886 - val_loss: 1.0299 - val_accuracy: 0.5234 - 6s/epoch - 321ms/step
# Epoch 84/100
# 20/20 - 6s - loss: 1.0269 - accuracy: 0.4821 - val_loss: 1.0316 - val_accuracy: 0.5312 - 6s/epoch - 323ms/step
# Epoch 85/100
# 20/20 - 7s - loss: 1.0153 - accuracy: 0.4594 - val_loss: 1.0346 - val_accuracy: 0.5000 - 7s/epoch - 363ms/step
# Epoch 86/100
# 20/20 - 8s - loss: 1.0145 - accuracy: 0.4692 - val_loss: 1.0365 - val_accuracy: 0.4375 - 8s/epoch - 388ms/step
# Epoch 87/100
# 20/20 - 8s - loss: 1.0201 - accuracy: 0.4708 - val_loss: 1.0259 - val_accuracy: 0.5625 - 8s/epoch - 413ms/step
# Epoch 88/100
# 20/20 - 9s - loss: 1.0095 - accuracy: 0.4951 - val_loss: 1.0330 - val_accuracy: 0.4766 - 9s/epoch - 430ms/step
# Epoch 89/100
# 20/20 - 6s - loss: 1.0273 - accuracy: 0.4627 - val_loss: 1.0310 - val_accuracy: 0.4453 - 6s/epoch - 325ms/step
# Epoch 90/100
# 20/20 - 6s - loss: 1.0116 - accuracy: 0.5032 - val_loss: 1.0328 - val_accuracy: 0.4609 - 6s/epoch - 315ms/step
# Epoch 91/100
# 20/20 - 7s - loss: 1.0108 - accuracy: 0.4903 - val_loss: 1.0367 - val_accuracy: 0.4766 - 7s/epoch - 330ms/step
# Epoch 92/100
# 20/20 - 6s - loss: 1.0089 - accuracy: 0.4740 - val_loss: 1.0294 - val_accuracy: 0.4844 - 6s/epoch - 316ms/step
# Epoch 93/100
# 20/20 - 6s - loss: 1.0141 - accuracy: 0.4659 - val_loss: 1.0201 - val_accuracy: 0.5156 - 6s/epoch - 321ms/step
# Epoch 94/100
# 20/20 - 8s - loss: 1.0188 - accuracy: 0.4968 - val_loss: 1.0218 - val_accuracy: 0.5234 - 8s/epoch - 385ms/step
# Epoch 95/100
# 20/20 - 8s - loss: 0.9940 - accuracy: 0.5195 - val_loss: 1.0327 - val_accuracy: 0.4531 - 8s/epoch - 392ms/step
# Epoch 96/100
# 20/20 - 8s - loss: 1.0186 - accuracy: 0.4773 - val_loss: 1.0267 - val_accuracy: 0.4609 - 8s/epoch - 393ms/step
# Epoch 97/100
# 20/20 - 7s - loss: 1.0151 - accuracy: 0.4659 - val_loss: 1.0330 - val_accuracy: 0.4844 - 7s/epoch - 334ms/step
# Epoch 98/100
# 20/20 - 6s - loss: 1.0401 - accuracy: 0.4594 - val_loss: 1.0283 - val_accuracy: 0.4375 - 6s/epoch - 324ms/step
# Epoch 99/100
# 20/20 - 7s - loss: 1.0089 - accuracy: 0.5114 - val_loss: 1.0262 - val_accuracy: 0.4922 - 7s/epoch - 329ms/step
# Epoch 100/100
# 20/20 - 6s - loss: 1.0319 - accuracy: 0.4756 - val_loss: 1.0230 - val_accuracy: 0.4922 - 6s/epoch - 322ms/step

# %%
# Plotting the training results
# %matplotlib inline

import matplotlib.image as mpimg
import matplotlib.pyplot as plt
#-----------------------------------------------------------
acc      = history.history[     'accuracy' ]
val_acc  = history.history[ 'val_accuracy' ]
loss     = history.history[    'loss' ]
val_loss = history.history['val_loss' ]

epochs   = range(len(acc)) # Get number of epochs

#------------------------------------------------
# Plot training and validation accuracy per epoch
#------------------------------------------------
plt.plot  ( epochs,     acc, label='Training')
plt.plot  ( epochs, val_acc, label='Validation')
plt.title ('Training and validation accuracy')
plt.legend()
plt.figure()

#------------------------------------------------
# Plot training and validation loss per epoch
#------------------------------------------------
plt.plot  ( epochs,     loss, label='Training')
plt.plot  ( epochs, val_loss, label='Validation')
plt.legend()
plt.title ('Training and validation loss')
# Out:
# Text(0.5, 1.0, 'Training and validation loss')

# %% [markdown]
# # **Training second Model with Alexnet architectur (Model A)**

# %%
model2 = tf.keras.Sequential([
    tf.keras.layers.Conv2D(96, 11, strides=4, activation='relu', padding='same', input_shape=(150, 150, 3)),
    tf.keras.layers.MaxPool2D(3, strides=2),
    tf.keras.layers.Conv2D(256, 5, strides=4, padding='same', activation='relu'),
    tf.keras.layers.MaxPool2D(3, strides=2),
    tf.keras.layers.Conv2D(384, 3, strides=4, padding='same', activation='relu'),
    tf.keras.layers.Conv2D(384, 3, strides=4, padding='same', activation='relu'),
    tf.keras.layers.Conv2D(256, 3, strides=4, padding='same', activation='relu'),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(4096, activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(4096, activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(3, activation='softmax')
])

model2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 38, 38, 96)        34944
#
#  max_pooling2d_3 (MaxPooling  (None, 18, 18, 96)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 5, 5, 256)         614656
#
#  max_pooling2d_4 (MaxPooling  (None, 2, 2, 256)        0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 1, 1, 384)         885120
#
#  conv2d_7 (Conv2D)           (None, 1, 1, 384)         1327488
#
#  conv2d_8 (Conv2D)           (None, 1, 1, 256)         884992
#
#  flatten_1 (Flatten)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 4096)              1052672
#
#  dropout_4 (Dropout)         (None, 4096)              0
#
#  dense_3 (Dense)             (None, 4096)              16781312
#
#  dropout_5 (Dropout)         (None, 4096)              0
#
#  dense_4 (Dense)             (None, 3)                 12291
#
# =================================================================
# Total params: 21,593,475
# Trainable params: 21,593,475
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import Adam
model2.compile(optimizer=Adam(learning_rate=lr_scheduler), loss='categorical_crossentropy', metrics=['accuracy'])

#Training proccess
history2 = model2.fit(
    train_generator,
    steps_per_epoch = train_generator.samples // 32,
    epochs = 100,
    validation_data = validation_generator,
    validation_steps = validation_generator.samples // 32,
    verbose = 2
    # callbacks=[callback]
)
# Out:
# Epoch 1/100
# 20/20 - 9s - loss: 1.0987 - accuracy: 0.3156 - val_loss: 1.0985 - val_accuracy: 0.3516 - 9s/epoch - 426ms/step
# Epoch 2/100
# 20/20 - 6s - loss: 1.0987 - accuracy: 0.3247 - val_loss: 1.0984 - val_accuracy: 0.3203 - 6s/epoch - 283ms/step
# Epoch 3/100
# 20/20 - 6s - loss: 1.0987 - accuracy: 0.3344 - val_loss: 1.0980 - val_accuracy: 0.3750 - 6s/epoch - 277ms/step
# Epoch 4/100
# 20/20 - 5s - loss: 1.0986 - accuracy: 0.3263 - val_loss: 1.0987 - val_accuracy: 0.3047 - 5s/epoch - 273ms/step
# Epoch 5/100
# 20/20 - 5s - loss: 1.0986 - accuracy: 0.3295 - val_loss: 1.0985 - val_accuracy: 0.3203 - 5s/epoch - 262ms/step
# Epoch 6/100
# 20/20 - 6s - loss: 1.0985 - accuracy: 0.3438 - val_loss: 1.0984 - val_accuracy: 0.3203 - 6s/epoch - 276ms/step
# Epoch 7/100
# 20/20 - 7s - loss: 1.0985 - accuracy: 0.3231 - val_loss: 1.0982 - val_accuracy: 0.3125 - 7s/epoch - 327ms/step
# Epoch 8/100
# 20/20 - 7s - loss: 1.0988 - accuracy: 0.3279 - val_loss: 1.0981 - val_accuracy: 0.3047 - 7s/epoch - 326ms/step
# Epoch 9/100
# 20/20 - 7s - loss: 1.0982 - accuracy: 0.3539 - val_loss: 1.0968 - val_accuracy: 0.3516 - 7s/epoch - 334ms/step
# Epoch 10/100
# 20/20 - 6s - loss: 1.0986 - accuracy: 0.3328 - val_loss: 1.0969 - val_accuracy: 0.5234 - 6s/epoch - 316ms/step
# Epoch 11/100
# 20/20 - 5s - loss: 1.0979 - accuracy: 0.3653 - val_loss: 1.0931 - val_accuracy: 0.3906 - 5s/epoch - 268ms/step
# Epoch 12/100
# 20/20 - 5s - loss: 1.0946 - accuracy: 0.4156 - val_loss: 1.0863 - val_accuracy: 0.3359 - 5s/epoch - 260ms/step
# Epoch 13/100
# 20/20 - 5s - loss: 1.0936 - accuracy: 0.3571 - val_loss: 1.0667 - val_accuracy: 0.4844 - 5s/epoch - 259ms/step
# Epoch 14/100
# 20/20 - 5s - loss: 1.0826 - accuracy: 0.4140 - val_loss: 1.0573 - val_accuracy: 0.5391 - 5s/epoch - 259ms/step
# Epoch 15/100
# 20/20 - 5s - loss: 1.0704 - accuracy: 0.4140 - val_loss: 1.0364 - val_accuracy: 0.4453 - 5s/epoch - 259ms/step
# Epoch 16/100
# 20/20 - 5s - loss: 1.0656 - accuracy: 0.4237 - val_loss: 1.0109 - val_accuracy: 0.4609 - 5s/epoch - 262ms/step
# Epoch 17/100
# 20/20 - 6s - loss: 1.0617 - accuracy: 0.4383 - val_loss: 1.0416 - val_accuracy: 0.4688 - 6s/epoch - 305ms/step
# Epoch 18/100
# 20/20 - 7s - loss: 1.0594 - accuracy: 0.4302 - val_loss: 1.0131 - val_accuracy: 0.5234 - 7s/epoch - 337ms/step
# Epoch 19/100
# 20/20 - 8s - loss: 1.0478 - accuracy: 0.4437 - val_loss: 1.0237 - val_accuracy: 0.4766 - 8s/epoch - 406ms/step
# Epoch 20/100
# 20/20 - 7s - loss: 1.0433 - accuracy: 0.4464 - val_loss: 1.0330 - val_accuracy: 0.4453 - 7s/epoch - 370ms/step
# Epoch 21/100
# 20/20 - 5s - loss: 1.0378 - accuracy: 0.4627 - val_loss: 0.9959 - val_accuracy: 0.5000 - 5s/epoch - 273ms/step
# Epoch 22/100
# 20/20 - 5s - loss: 1.0418 - accuracy: 0.4659 - val_loss: 0.9781 - val_accuracy: 0.5000 - 5s/epoch - 266ms/step
# Epoch 23/100
# 20/20 - 5s - loss: 1.0300 - accuracy: 0.4773 - val_loss: 0.9974 - val_accuracy: 0.5078 - 5s/epoch - 260ms/step
# Epoch 24/100
# 20/20 - 5s - loss: 1.0327 - accuracy: 0.4529 - val_loss: 0.9860 - val_accuracy: 0.5312 - 5s/epoch - 259ms/step
# Epoch 25/100
# 20/20 - 6s - loss: 1.0234 - accuracy: 0.4903 - val_loss: 0.9875 - val_accuracy: 0.5156 - 6s/epoch - 281ms/step
# Epoch 26/100
# 20/20 - 5s - loss: 1.0123 - accuracy: 0.4724 - val_loss: 1.0039 - val_accuracy: 0.5234 - 5s/epoch - 261ms/step
# Epoch 27/100
# 20/20 - 6s - loss: 1.0198 - accuracy: 0.4886 - val_loss: 0.9778 - val_accuracy: 0.5234 - 6s/epoch - 296ms/step
# Epoch 28/100
# 20/20 - 6s - loss: 1.0001 - accuracy: 0.4968 - val_loss: 0.9612 - val_accuracy: 0.5391 - 6s/epoch - 278ms/step
# Epoch 29/100
# 20/20 - 5s - loss: 1.0053 - accuracy: 0.4903 - val_loss: 0.9892 - val_accuracy: 0.5469 - 5s/epoch - 268ms/step
# Epoch 30/100
# 20/20 - 7s - loss: 1.0117 - accuracy: 0.5049 - val_loss: 0.9390 - val_accuracy: 0.5469 - 7s/epoch - 338ms/step
# Epoch 31/100
# 20/20 - 7s - loss: 0.9930 - accuracy: 0.4951 - val_loss: 0.9530 - val_accuracy: 0.5469 - 7s/epoch - 347ms/step
# Epoch 32/100
# 20/20 - 5s - loss: 1.0034 - accuracy: 0.4969 - val_loss: 0.9673 - val_accuracy: 0.5469 - 5s/epoch - 265ms/step
# Epoch 33/100
# 20/20 - 5s - loss: 0.9963 - accuracy: 0.4968 - val_loss: 1.0083 - val_accuracy: 0.4766 - 5s/epoch - 274ms/step
# Epoch 34/100
# 20/20 - 5s - loss: 0.9959 - accuracy: 0.5146 - val_loss: 0.9747 - val_accuracy: 0.5078 - 5s/epoch - 266ms/step
# Epoch 35/100
# 20/20 - 6s - loss: 0.9997 - accuracy: 0.4968 - val_loss: 0.9552 - val_accuracy: 0.5234 - 6s/epoch - 278ms/step
# Epoch 36/100
# 20/20 - 5s - loss: 1.0008 - accuracy: 0.4951 - val_loss: 0.9687 - val_accuracy: 0.5391 - 5s/epoch - 261ms/step
# Epoch 37/100
# 20/20 - 5s - loss: 0.9925 - accuracy: 0.5032 - val_loss: 0.9759 - val_accuracy: 0.5312 - 5s/epoch - 269ms/step
# Epoch 38/100
# 20/20 - 7s - loss: 0.9687 - accuracy: 0.5244 - val_loss: 0.9701 - val_accuracy: 0.5391 - 7s/epoch - 326ms/step
# Epoch 39/100
# 20/20 - 7s - loss: 0.9637 - accuracy: 0.5391 - val_loss: 0.9327 - val_accuracy: 0.5938 - 7s/epoch - 341ms/step
# Epoch 40/100
# 20/20 - 6s - loss: 0.9917 - accuracy: 0.5032 - val_loss: 0.9307 - val_accuracy: 0.5625 - 6s/epoch - 316ms/step
# Epoch 41/100
# 20/20 - 6s - loss: 0.9760 - accuracy: 0.5292 - val_loss: 0.9473 - val_accuracy: 0.5625 - 6s/epoch - 291ms/step
# Epoch 42/100
# 20/20 - 5s - loss: 0.9607 - accuracy: 0.5244 - val_loss: 0.9286 - val_accuracy: 0.5391 - 5s/epoch - 272ms/step
# Epoch 43/100
# 20/20 - 5s - loss: 0.9967 - accuracy: 0.5114 - val_loss: 0.9247 - val_accuracy: 0.5703 - 5s/epoch - 260ms/step
# Epoch 44/100
# 20/20 - 5s - loss: 0.9520 - accuracy: 0.5609 - val_loss: 0.9393 - val_accuracy: 0.5312 - 5s/epoch - 267ms/step
# Epoch 45/100
# 20/20 - 5s - loss: 0.9604 - accuracy: 0.5292 - val_loss: 0.9142 - val_accuracy: 0.5234 - 5s/epoch - 259ms/step
# Epoch 46/100
# 20/20 - 5s - loss: 0.9653 - accuracy: 0.5438 - val_loss: 0.9238 - val_accuracy: 0.5547 - 5s/epoch - 261ms/step
# Epoch 47/100
# 20/20 - 6s - loss: 0.9559 - accuracy: 0.5552 - val_loss: 0.9778 - val_accuracy: 0.5391 - 6s/epoch - 279ms/step
# Epoch 48/100
# 20/20 - 6s - loss: 0.9251 - accuracy: 0.5617 - val_loss: 0.9109 - val_accuracy: 0.5469 - 6s/epoch - 310ms/step
# Epoch 49/100
# 20/20 - 7s - loss: 0.9370 - accuracy: 0.5455 - val_loss: 0.8989 - val_accuracy: 0.5781 - 7s/epoch - 330ms/step
# Epoch 50/100
# 20/20 - 7s - loss: 0.9393 - accuracy: 0.5601 - val_loss: 0.9071 - val_accuracy: 0.5938 - 7s/epoch - 326ms/step
# Epoch 51/100
# 20/20 - 6s - loss: 0.9408 - accuracy: 0.5633 - val_loss: 0.9033 - val_accuracy: 0.6094 - 6s/epoch - 320ms/step
# Epoch 52/100
# 20/20 - 5s - loss: 0.9199 - accuracy: 0.5714 - val_loss: 0.9011 - val_accuracy: 0.6094 - 5s/epoch - 275ms/step
# Epoch 53/100
# 20/20 - 5s - loss: 0.9298 - accuracy: 0.5503 - val_loss: 0.9155 - val_accuracy: 0.5781 - 5s/epoch - 260ms/step
# Epoch 54/100
# 20/20 - 5s - loss: 0.9282 - accuracy: 0.5714 - val_loss: 0.8977 - val_accuracy: 0.6328 - 5s/epoch - 271ms/step
# Epoch 55/100
# 20/20 - 5s - loss: 0.9149 - accuracy: 0.5942 - val_loss: 0.8912 - val_accuracy: 0.6406 - 5s/epoch - 259ms/step
# Epoch 56/100
# 20/20 - 5s - loss: 0.9012 - accuracy: 0.5860 - val_loss: 0.9780 - val_accuracy: 0.5234 - 5s/epoch - 259ms/step
# Epoch 57/100
# 20/20 - 5s - loss: 0.9263 - accuracy: 0.5828 - val_loss: 0.9447 - val_accuracy: 0.5859 - 5s/epoch - 269ms/step
# Epoch 58/100
# 20/20 - 6s - loss: 0.9350 - accuracy: 0.5568 - val_loss: 0.9158 - val_accuracy: 0.6172 - 6s/epoch - 286ms/step
# Epoch 59/100
# 20/20 - 7s - loss: 0.9252 - accuracy: 0.5795 - val_loss: 0.8902 - val_accuracy: 0.6094 - 7s/epoch - 334ms/step
# Epoch 60/100
# 20/20 - 7s - loss: 0.9006 - accuracy: 0.5974 - val_loss: 0.9358 - val_accuracy: 0.5859 - 7s/epoch - 327ms/step
# Epoch 61/100
# 20/20 - 7s - loss: 0.9188 - accuracy: 0.5552 - val_loss: 0.9314 - val_accuracy: 0.6016 - 7s/epoch - 328ms/step
# Epoch 62/100
# 20/20 - 6s - loss: 0.8919 - accuracy: 0.6120 - val_loss: 0.9065 - val_accuracy: 0.5938 - 6s/epoch - 315ms/step
# Epoch 63/100
# 20/20 - 6s - loss: 0.9121 - accuracy: 0.5633 - val_loss: 0.8884 - val_accuracy: 0.5781 - 6s/epoch - 307ms/step
# Epoch 64/100
# 20/20 - 5s - loss: 0.9197 - accuracy: 0.5828 - val_loss: 0.8279 - val_accuracy: 0.6406 - 5s/epoch - 266ms/step
# Epoch 65/100
# 20/20 - 6s - loss: 0.8955 - accuracy: 0.5990 - val_loss: 0.8863 - val_accuracy: 0.6172 - 6s/epoch - 304ms/step
# Epoch 66/100
# 20/20 - 6s - loss: 0.8964 - accuracy: 0.6088 - val_loss: 0.9076 - val_accuracy: 0.6172 - 6s/epoch - 290ms/step
# Epoch 67/100
# 20/20 - 6s - loss: 0.8744 - accuracy: 0.6006 - val_loss: 0.9454 - val_accuracy: 0.5781 - 6s/epoch - 276ms/step
# Epoch 68/100
# 20/20 - 6s - loss: 0.9026 - accuracy: 0.5925 - val_loss: 0.9530 - val_accuracy: 0.5859 - 6s/epoch - 309ms/step
# Epoch 69/100
# 20/20 - 7s - loss: 0.8818 - accuracy: 0.5990 - val_loss: 0.9220 - val_accuracy: 0.6016 - 7s/epoch - 344ms/step
# Epoch 70/100
# 20/20 - 7s - loss: 0.8902 - accuracy: 0.5909 - val_loss: 0.8396 - val_accuracy: 0.6406 - 7s/epoch - 341ms/step
# Epoch 71/100
# 20/20 - 6s - loss: 0.8844 - accuracy: 0.5990 - val_loss: 0.9426 - val_accuracy: 0.5859 - 6s/epoch - 306ms/step
# Epoch 72/100
# 20/20 - 6s - loss: 0.9010 - accuracy: 0.5893 - val_loss: 0.9760 - val_accuracy: 0.5391 - 6s/epoch - 304ms/step
# Epoch 73/100
# 20/20 - 5s - loss: 0.9144 - accuracy: 0.5763 - val_loss: 0.8846 - val_accuracy: 0.6328 - 5s/epoch - 261ms/step
# Epoch 74/100
# 20/20 - 5s - loss: 0.8708 - accuracy: 0.6282 - val_loss: 0.9010 - val_accuracy: 0.6250 - 5s/epoch - 263ms/step
# Epoch 75/100
# 20/20 - 5s - loss: 0.8748 - accuracy: 0.5990 - val_loss: 0.8959 - val_accuracy: 0.6250 - 5s/epoch - 260ms/step
# Epoch 76/100
# 20/20 - 5s - loss: 0.8824 - accuracy: 0.5925 - val_loss: 0.8401 - val_accuracy: 0.6250 - 5s/epoch - 259ms/step
# Epoch 77/100
# 20/20 - 5s - loss: 0.8668 - accuracy: 0.6120 - val_loss: 0.8845 - val_accuracy: 0.6328 - 5s/epoch - 259ms/step
# Epoch 78/100
# 20/20 - 5s - loss: 0.8505 - accuracy: 0.6282 - val_loss: 0.9259 - val_accuracy: 0.6406 - 5s/epoch - 274ms/step
# Epoch 79/100
# 20/20 - 7s - loss: 0.8646 - accuracy: 0.6136 - val_loss: 0.8905 - val_accuracy: 0.6016 - 7s/epoch - 327ms/step
# Epoch 80/100
# 20/20 - 7s - loss: 0.8705 - accuracy: 0.6120 - val_loss: 0.8797 - val_accuracy: 0.6328 - 7s/epoch - 337ms/step
# Epoch 81/100
# 20/20 - 8s - loss: 0.8504 - accuracy: 0.6299 - val_loss: 0.8855 - val_accuracy: 0.6016 - 8s/epoch - 377ms/step
# Epoch 82/100
# 20/20 - 7s - loss: 0.8621 - accuracy: 0.6331 - val_loss: 0.9094 - val_accuracy: 0.6094 - 7s/epoch - 330ms/step
# Epoch 83/100
# 20/20 - 5s - loss: 0.8522 - accuracy: 0.6266 - val_loss: 0.8987 - val_accuracy: 0.6172 - 5s/epoch - 266ms/step
# Epoch 84/100
# 20/20 - 5s - loss: 0.8422 - accuracy: 0.6218 - val_loss: 0.8500 - val_accuracy: 0.6719 - 5s/epoch - 266ms/step
# Epoch 85/100
# 20/20 - 5s - loss: 0.8638 - accuracy: 0.6104 - val_loss: 0.9065 - val_accuracy: 0.6094 - 5s/epoch - 261ms/step
# Epoch 86/100
# 20/20 - 5s - loss: 0.8629 - accuracy: 0.6218 - val_loss: 0.9037 - val_accuracy: 0.6094 - 5s/epoch - 265ms/step
# Epoch 87/100
# 20/20 - 5s - loss: 0.8594 - accuracy: 0.6006 - val_loss: 0.9163 - val_accuracy: 0.6016 - 5s/epoch - 271ms/step
# Epoch 88/100
# 20/20 - 5s - loss: 0.8534 - accuracy: 0.6169 - val_loss: 0.9102 - val_accuracy: 0.6094 - 5s/epoch - 273ms/step
# Epoch 89/100
# 20/20 - 7s - loss: 0.8621 - accuracy: 0.6039 - val_loss: 0.8571 - val_accuracy: 0.6562 - 7s/epoch - 330ms/step
# Epoch 90/100
# 20/20 - 6s - loss: 0.8662 - accuracy: 0.6055 - val_loss: 0.8929 - val_accuracy: 0.6250 - 6s/epoch - 316ms/step
# Epoch 91/100
# 20/20 - 6s - loss: 0.8387 - accuracy: 0.6266 - val_loss: 0.8624 - val_accuracy: 0.6484 - 6s/epoch - 323ms/step
# Epoch 92/100
# 20/20 - 6s - loss: 0.8629 - accuracy: 0.6169 - val_loss: 0.9082 - val_accuracy: 0.6094 - 6s/epoch - 297ms/step
# Epoch 93/100
# 20/20 - 6s - loss: 0.8457 - accuracy: 0.6234 - val_loss: 0.8684 - val_accuracy: 0.6406 - 6s/epoch - 289ms/step
# Epoch 94/100
# 20/20 - 5s - loss: 0.8363 - accuracy: 0.6364 - val_loss: 0.8400 - val_accuracy: 0.6406 - 5s/epoch - 271ms/step
# Epoch 95/100
# 20/20 - 5s - loss: 0.8509 - accuracy: 0.6250 - val_loss: 0.9114 - val_accuracy: 0.5859 - 5s/epoch - 267ms/step
# Epoch 96/100
# 20/20 - 5s - loss: 0.8374 - accuracy: 0.6299 - val_loss: 0.8803 - val_accuracy: 0.6250 - 5s/epoch - 262ms/step
# Epoch 97/100
# 20/20 - 5s - loss: 0.8494 - accuracy: 0.6331 - val_loss: 0.8776 - val_accuracy: 0.6641 - 5s/epoch - 262ms/step
# Epoch 98/100
# 20/20 - 5s - loss: 0.8500 - accuracy: 0.6234 - val_loss: 0.8674 - val_accuracy: 0.6328 - 5s/epoch - 260ms/step
# Epoch 99/100
# 20/20 - 7s - loss: 0.8479 - accuracy: 0.6364 - val_loss: 0.8605 - val_accuracy: 0.6562 - 7s/epoch - 327ms/step
# Epoch 100/100
# 20/20 - 7s - loss: 0.8332 - accuracy: 0.6445 - val_loss: 0.8888 - val_accuracy: 0.6406 - 7s/epoch - 333ms/step

# %%
#Plotting the results of the second model
acc2      = history2.history[     'accuracy' ]
val_acc2  = history2.history[ 'val_accuracy' ]
loss2     = history2.history[    'loss' ]
val_loss2 = history2.history['val_loss' ]

epochs2   = range(len(acc2)) # Get number of epochs

#------------------------------------------------
# Plot training and validation accuracy per epoch
#------------------------------------------------
plt.plot  ( epochs2,     acc2, label='Training')
plt.plot  ( epochs2, val_acc2, label='Validation')
plt.title ('Training and validation accuracy')
plt.legend()
plt.figure()

#------------------------------------------------
# Plot training and validation loss per epoch
#------------------------------------------------
plt.plot  ( epochs2,     loss2, label='Training')
plt.plot  ( epochs2, val_loss2, label='Validation')
plt.legend()
plt.title ('Training and validation loss')
# Out:
# Text(0.5, 1.0, 'Training and validation loss')

# %% [markdown]
# # **LeNet Architecture (Model B)**

# %%
model3 = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(6, (5, 5), activation='relu', input_shape=(150, 150, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Conv2D(16, (5, 5), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(120, activation='relu'),
    tf.keras.layers.Dense(84, activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(3, activation='softmax')
])

model3.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_9 (Conv2D)           (None, 146, 146, 6)       456
#
#  max_pooling2d_5 (MaxPooling  (None, 73, 73, 6)        0
#  2D)
#
#  dropout_6 (Dropout)         (None, 73, 73, 6)         0
#
#  conv2d_10 (Conv2D)          (None, 69, 69, 16)        2416
#
#  max_pooling2d_6 (MaxPooling  (None, 34, 34, 16)       0
#  2D)
#
#  dropout_7 (Dropout)         (None, 34, 34, 16)        0
#
#  flatten_2 (Flatten)         (None, 18496)             0
#
#  dense_5 (Dense)             (None, 120)               2219640
#
#  dense_6 (Dense)             (None, 84)                10164
#
#  dropout_8 (Dropout)         (None, 84)                0
#
#  dense_7 (Dense)             (None, 3)                 255
#
# =================================================================
# Total params: 2,232,931
# Trainable params: 2,232,931
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import Adam
model3.compile(optimizer=Adam(learning_rate=lr_scheduler), loss='categorical_crossentropy', metrics=['accuracy'])

#Training proccess
history3 = model3.fit(
    train_generator,
    steps_per_epoch = train_generator.samples // 32,
    epochs = 100,
    validation_data = validation_generator,
    validation_steps = validation_generator.samples // 32,
    verbose = 2
    # callbacks=[callback]
)
# Out:
# Epoch 1/100
# 20/20 - 7s - loss: 1.2462 - accuracy: 0.3344 - val_loss: 1.0889 - val_accuracy: 0.3984 - 7s/epoch - 348ms/step
# Epoch 2/100
# 20/20 - 7s - loss: 1.1270 - accuracy: 0.3994 - val_loss: 1.0744 - val_accuracy: 0.4609 - 7s/epoch - 326ms/step
# Epoch 3/100
# 20/20 - 6s - loss: 1.1436 - accuracy: 0.3766 - val_loss: 1.0532 - val_accuracy: 0.4219 - 6s/epoch - 318ms/step
# Epoch 4/100
# 20/20 - 6s - loss: 1.1401 - accuracy: 0.3490 - val_loss: 1.0428 - val_accuracy: 0.5000 - 6s/epoch - 312ms/step
# Epoch 5/100
# 20/20 - 7s - loss: 1.1127 - accuracy: 0.3636 - val_loss: 1.0534 - val_accuracy: 0.4375 - 7s/epoch - 327ms/step
# Epoch 6/100
# 20/20 - 8s - loss: 1.0889 - accuracy: 0.3896 - val_loss: 1.0455 - val_accuracy: 0.4922 - 8s/epoch - 383ms/step
# Epoch 7/100
# 20/20 - 8s - loss: 1.0907 - accuracy: 0.3847 - val_loss: 1.0733 - val_accuracy: 0.3594 - 8s/epoch - 402ms/step
# Epoch 8/100
# 20/20 - 8s - loss: 1.0969 - accuracy: 0.3703 - val_loss: 1.0419 - val_accuracy: 0.4609 - 8s/epoch - 381ms/step
# Epoch 9/100
# 20/20 - 6s - loss: 1.0804 - accuracy: 0.4221 - val_loss: 1.0634 - val_accuracy: 0.4375 - 6s/epoch - 324ms/step
# Epoch 10/100
# 20/20 - 7s - loss: 1.0878 - accuracy: 0.4156 - val_loss: 1.0589 - val_accuracy: 0.4609 - 7s/epoch - 326ms/step
# Epoch 11/100
# 20/20 - 6s - loss: 1.0742 - accuracy: 0.4172 - val_loss: 1.0525 - val_accuracy: 0.4609 - 6s/epoch - 315ms/step
# Epoch 12/100
# 20/20 - 6s - loss: 1.0758 - accuracy: 0.4123 - val_loss: 1.0507 - val_accuracy: 0.5312 - 6s/epoch - 287ms/step
# Epoch 13/100
# 20/20 - 5s - loss: 1.0557 - accuracy: 0.4448 - val_loss: 1.0498 - val_accuracy: 0.3984 - 5s/epoch - 245ms/step
# Epoch 14/100
# 20/20 - 5s - loss: 1.0955 - accuracy: 0.4107 - val_loss: 1.0455 - val_accuracy: 0.5156 - 5s/epoch - 248ms/step
# Epoch 15/100
# 20/20 - 6s - loss: 1.0756 - accuracy: 0.4042 - val_loss: 1.0483 - val_accuracy: 0.4531 - 6s/epoch - 284ms/step
# Epoch 16/100
# 20/20 - 5s - loss: 1.0629 - accuracy: 0.4432 - val_loss: 1.0643 - val_accuracy: 0.4453 - 5s/epoch - 271ms/step
# Epoch 17/100
# 20/20 - 5s - loss: 1.0695 - accuracy: 0.4075 - val_loss: 1.0425 - val_accuracy: 0.4922 - 5s/epoch - 247ms/step
# Epoch 18/100
# 20/20 - 5s - loss: 1.0775 - accuracy: 0.4269 - val_loss: 1.0472 - val_accuracy: 0.5156 - 5s/epoch - 246ms/step
# Epoch 19/100
# 20/20 - 5s - loss: 1.0704 - accuracy: 0.4172 - val_loss: 1.0475 - val_accuracy: 0.4453 - 5s/epoch - 246ms/step
# Epoch 20/100
# 20/20 - 5s - loss: 1.0558 - accuracy: 0.4399 - val_loss: 1.0313 - val_accuracy: 0.4766 - 5s/epoch - 246ms/step
# Epoch 21/100
# 20/20 - 5s - loss: 1.0502 - accuracy: 0.4464 - val_loss: 1.0462 - val_accuracy: 0.4609 - 5s/epoch - 246ms/step
# Epoch 22/100
# 20/20 - 5s - loss: 1.0655 - accuracy: 0.4269 - val_loss: 1.0391 - val_accuracy: 0.4844 - 5s/epoch - 247ms/step
# Epoch 23/100
# 20/20 - 5s - loss: 1.0712 - accuracy: 0.4075 - val_loss: 1.0386 - val_accuracy: 0.4922 - 5s/epoch - 244ms/step
# Epoch 24/100
# 20/20 - 5s - loss: 1.0613 - accuracy: 0.4313 - val_loss: 1.0378 - val_accuracy: 0.4766 - 5s/epoch - 271ms/step
# Epoch 25/100
# 20/20 - 5s - loss: 1.0562 - accuracy: 0.4529 - val_loss: 1.0260 - val_accuracy: 0.5391 - 5s/epoch - 246ms/step
# Epoch 26/100
# 20/20 - 5s - loss: 1.0433 - accuracy: 0.4416 - val_loss: 1.0317 - val_accuracy: 0.4922 - 5s/epoch - 270ms/step
# Epoch 27/100
# 20/20 - 7s - loss: 1.0590 - accuracy: 0.4448 - val_loss: 1.0379 - val_accuracy: 0.4844 - 7s/epoch - 329ms/step
# Epoch 28/100
# 20/20 - 6s - loss: 1.0607 - accuracy: 0.4659 - val_loss: 1.0522 - val_accuracy: 0.4219 - 6s/epoch - 321ms/step
# Epoch 29/100
# 20/20 - 7s - loss: 1.0596 - accuracy: 0.4399 - val_loss: 1.0359 - val_accuracy: 0.4375 - 7s/epoch - 365ms/step
# Epoch 30/100
# 20/20 - 7s - loss: 1.0610 - accuracy: 0.4286 - val_loss: 1.0373 - val_accuracy: 0.4922 - 7s/epoch - 330ms/step
# Epoch 31/100
# 20/20 - 5s - loss: 1.0596 - accuracy: 0.4399 - val_loss: 1.0454 - val_accuracy: 0.4531 - 5s/epoch - 244ms/step
# Epoch 32/100
# 20/20 - 5s - loss: 1.0445 - accuracy: 0.4448 - val_loss: 1.0405 - val_accuracy: 0.4766 - 5s/epoch - 250ms/step
# Epoch 33/100
# 20/20 - 5s - loss: 1.0606 - accuracy: 0.4318 - val_loss: 1.0345 - val_accuracy: 0.5078 - 5s/epoch - 247ms/step
# Epoch 34/100
# 20/20 - 5s - loss: 1.0458 - accuracy: 0.4399 - val_loss: 1.0248 - val_accuracy: 0.4609 - 5s/epoch - 245ms/step
# Epoch 35/100
# 20/20 - 5s - loss: 1.0327 - accuracy: 0.4734 - val_loss: 1.0247 - val_accuracy: 0.4922 - 5s/epoch - 267ms/step
# Epoch 36/100
# 20/20 - 5s - loss: 1.0439 - accuracy: 0.4578 - val_loss: 1.0362 - val_accuracy: 0.5000 - 5s/epoch - 245ms/step
# Epoch 37/100
# 20/20 - 6s - loss: 1.0466 - accuracy: 0.4578 - val_loss: 1.0266 - val_accuracy: 0.4609 - 6s/epoch - 301ms/step
# Epoch 38/100
# 20/20 - 6s - loss: 1.0581 - accuracy: 0.4269 - val_loss: 1.0222 - val_accuracy: 0.4766 - 6s/epoch - 310ms/step
# Epoch 39/100
# 20/20 - 7s - loss: 1.0377 - accuracy: 0.4594 - val_loss: 1.0394 - val_accuracy: 0.4219 - 7s/epoch - 334ms/step
# Epoch 40/100
# 20/20 - 6s - loss: 1.0445 - accuracy: 0.4724 - val_loss: 1.0210 - val_accuracy: 0.4531 - 6s/epoch - 285ms/step
# Epoch 41/100
# 20/20 - 5s - loss: 1.0463 - accuracy: 0.4448 - val_loss: 1.0134 - val_accuracy: 0.5156 - 5s/epoch - 275ms/step
# Epoch 42/100
# 20/20 - 5s - loss: 1.0580 - accuracy: 0.4610 - val_loss: 1.0261 - val_accuracy: 0.4766 - 5s/epoch - 244ms/step
# Epoch 43/100
# 20/20 - 5s - loss: 1.0589 - accuracy: 0.4221 - val_loss: 1.0316 - val_accuracy: 0.4922 - 5s/epoch - 244ms/step
# Epoch 44/100
# 20/20 - 5s - loss: 1.0415 - accuracy: 0.4497 - val_loss: 1.0385 - val_accuracy: 0.4844 - 5s/epoch - 245ms/step
# Epoch 45/100
# 20/20 - 5s - loss: 1.0351 - accuracy: 0.4545 - val_loss: 1.0209 - val_accuracy: 0.5000 - 5s/epoch - 244ms/step
# Epoch 46/100
# 20/20 - 5s - loss: 1.0357 - accuracy: 0.4497 - val_loss: 1.0269 - val_accuracy: 0.4609 - 5s/epoch - 245ms/step
# Epoch 47/100
# 20/20 - 5s - loss: 1.0506 - accuracy: 0.4610 - val_loss: 1.0238 - val_accuracy: 0.5391 - 5s/epoch - 246ms/step
# Epoch 48/100
# 20/20 - 6s - loss: 1.0273 - accuracy: 0.4854 - val_loss: 1.0134 - val_accuracy: 0.5000 - 6s/epoch - 295ms/step
# Epoch 49/100
# 20/20 - 6s - loss: 1.0397 - accuracy: 0.4464 - val_loss: 1.0202 - val_accuracy: 0.4609 - 6s/epoch - 310ms/step
# Epoch 50/100
# 20/20 - 7s - loss: 1.0294 - accuracy: 0.4805 - val_loss: 1.0208 - val_accuracy: 0.4609 - 7s/epoch - 327ms/step
# Epoch 51/100
# 20/20 - 6s - loss: 1.0432 - accuracy: 0.4481 - val_loss: 1.0327 - val_accuracy: 0.4922 - 6s/epoch - 286ms/step
# Epoch 52/100
# 20/20 - 5s - loss: 1.0286 - accuracy: 0.4821 - val_loss: 1.0215 - val_accuracy: 0.4453 - 5s/epoch - 274ms/step
# Epoch 53/100
# 20/20 - 5s - loss: 1.0385 - accuracy: 0.4675 - val_loss: 1.0261 - val_accuracy: 0.4922 - 5s/epoch - 247ms/step
# Epoch 54/100
# 20/20 - 5s - loss: 1.0365 - accuracy: 0.4594 - val_loss: 1.0331 - val_accuracy: 0.4844 - 5s/epoch - 245ms/step
# Epoch 55/100
# 20/20 - 5s - loss: 1.0206 - accuracy: 0.4643 - val_loss: 1.0196 - val_accuracy: 0.4688 - 5s/epoch - 244ms/step
# Epoch 56/100
# 20/20 - 5s - loss: 1.0275 - accuracy: 0.4703 - val_loss: 1.0284 - val_accuracy: 0.4453 - 5s/epoch - 253ms/step
# Epoch 57/100
# 20/20 - 5s - loss: 1.0219 - accuracy: 0.4610 - val_loss: 1.0264 - val_accuracy: 0.4609 - 5s/epoch - 244ms/step
# Epoch 58/100
# 20/20 - 9s - loss: 1.0283 - accuracy: 0.4789 - val_loss: 1.0015 - val_accuracy: 0.4922 - 9s/epoch - 455ms/step
# Epoch 59/100
# 20/20 - 6s - loss: 1.0457 - accuracy: 0.4464 - val_loss: 1.0075 - val_accuracy: 0.5547 - 6s/epoch - 322ms/step
# Epoch 60/100
# 20/20 - 6s - loss: 1.0247 - accuracy: 0.4951 - val_loss: 1.0192 - val_accuracy: 0.5156 - 6s/epoch - 317ms/step
# Epoch 61/100
# 20/20 - 6s - loss: 1.0304 - accuracy: 0.4529 - val_loss: 1.0161 - val_accuracy: 0.5000 - 6s/epoch - 325ms/step
# Epoch 62/100
# 20/20 - 6s - loss: 1.0302 - accuracy: 0.4870 - val_loss: 1.0332 - val_accuracy: 0.4453 - 6s/epoch - 281ms/step
# Epoch 63/100
# 20/20 - 5s - loss: 1.0339 - accuracy: 0.4545 - val_loss: 1.0202 - val_accuracy: 0.5234 - 5s/epoch - 266ms/step
# Epoch 64/100
# 20/20 - 5s - loss: 1.0316 - accuracy: 0.4903 - val_loss: 1.0174 - val_accuracy: 0.5000 - 5s/epoch - 244ms/step
# Epoch 65/100
# 20/20 - 5s - loss: 1.0313 - accuracy: 0.4773 - val_loss: 1.0246 - val_accuracy: 0.4609 - 5s/epoch - 258ms/step
# Epoch 66/100
# 20/20 - 5s - loss: 1.0289 - accuracy: 0.4513 - val_loss: 1.0178 - val_accuracy: 0.5000 - 5s/epoch - 266ms/step
# Epoch 67/100
# 20/20 - 5s - loss: 1.0111 - accuracy: 0.4984 - val_loss: 1.0163 - val_accuracy: 0.5000 - 5s/epoch - 258ms/step
# Epoch 68/100
# 20/20 - 5s - loss: 1.0199 - accuracy: 0.4919 - val_loss: 1.0181 - val_accuracy: 0.5078 - 5s/epoch - 246ms/step
# Epoch 69/100
# 20/20 - 6s - loss: 1.0297 - accuracy: 0.4399 - val_loss: 1.0114 - val_accuracy: 0.4922 - 6s/epoch - 297ms/step
# Epoch 70/100
# 20/20 - 6s - loss: 1.0303 - accuracy: 0.4773 - val_loss: 1.0168 - val_accuracy: 0.5156 - 6s/epoch - 321ms/step
# Epoch 71/100
# 20/20 - 6s - loss: 1.0412 - accuracy: 0.4399 - val_loss: 1.0225 - val_accuracy: 0.5078 - 6s/epoch - 320ms/step
# Epoch 72/100
# 20/20 - 6s - loss: 1.0330 - accuracy: 0.4594 - val_loss: 1.0242 - val_accuracy: 0.5078 - 6s/epoch - 302ms/step
# Epoch 73/100
# 20/20 - 6s - loss: 1.0263 - accuracy: 0.4789 - val_loss: 1.0264 - val_accuracy: 0.4531 - 6s/epoch - 293ms/step
# Epoch 74/100
# 20/20 - 5s - loss: 1.0046 - accuracy: 0.4968 - val_loss: 1.0047 - val_accuracy: 0.5234 - 5s/epoch - 244ms/step
# Epoch 75/100
# 20/20 - 5s - loss: 1.0363 - accuracy: 0.4318 - val_loss: 1.0108 - val_accuracy: 0.5078 - 5s/epoch - 245ms/step
# Epoch 76/100
# 20/20 - 5s - loss: 1.0202 - accuracy: 0.4724 - val_loss: 1.0169 - val_accuracy: 0.4688 - 5s/epoch - 252ms/step
# Epoch 77/100
# 20/20 - 5s - loss: 1.0298 - accuracy: 0.4610 - val_loss: 1.0226 - val_accuracy: 0.4844 - 5s/epoch - 248ms/step
# Epoch 78/100
# 20/20 - 5s - loss: 1.0286 - accuracy: 0.4708 - val_loss: 1.0138 - val_accuracy: 0.4766 - 5s/epoch - 246ms/step
# Epoch 79/100
# 20/20 - 5s - loss: 1.0275 - accuracy: 0.4838 - val_loss: 1.0230 - val_accuracy: 0.4688 - 5s/epoch - 247ms/step
# Epoch 80/100
# 20/20 - 6s - loss: 1.0273 - accuracy: 0.4951 - val_loss: 1.0318 - val_accuracy: 0.4609 - 6s/epoch - 298ms/step
# Epoch 81/100
# 20/20 - 7s - loss: 1.0284 - accuracy: 0.4740 - val_loss: 1.0257 - val_accuracy: 0.5312 - 7s/epoch - 333ms/step
# Epoch 82/100
# 20/20 - 6s - loss: 1.0272 - accuracy: 0.4643 - val_loss: 1.0175 - val_accuracy: 0.5312 - 6s/epoch - 316ms/step
# Epoch 83/100
# 20/20 - 8s - loss: 1.0412 - accuracy: 0.4269 - val_loss: 1.0156 - val_accuracy: 0.5469 - 8s/epoch - 378ms/step
# Epoch 84/100
# 20/20 - 6s - loss: 1.0212 - accuracy: 0.4627 - val_loss: 1.0299 - val_accuracy: 0.4766 - 6s/epoch - 291ms/step
# Epoch 85/100
# 20/20 - 5s - loss: 1.0148 - accuracy: 0.4740 - val_loss: 1.0141 - val_accuracy: 0.5234 - 5s/epoch - 245ms/step
# Epoch 86/100
# 20/20 - 5s - loss: 1.0182 - accuracy: 0.4773 - val_loss: 1.0171 - val_accuracy: 0.4922 - 5s/epoch - 252ms/step
# Epoch 87/100
# 20/20 - 5s - loss: 1.0371 - accuracy: 0.4594 - val_loss: 1.0073 - val_accuracy: 0.5469 - 5s/epoch - 243ms/step
# Epoch 88/100
# 20/20 - 5s - loss: 1.0340 - accuracy: 0.4821 - val_loss: 1.0261 - val_accuracy: 0.5312 - 5s/epoch - 245ms/step
# Epoch 89/100
# 20/20 - 5s - loss: 1.0093 - accuracy: 0.4870 - val_loss: 1.0096 - val_accuracy: 0.5234 - 5s/epoch - 249ms/step
# Epoch 90/100
# 20/20 - 5s - loss: 1.0258 - accuracy: 0.4562 - val_loss: 1.0145 - val_accuracy: 0.4531 - 5s/epoch - 261ms/step
# Epoch 91/100
# 20/20 - 6s - loss: 1.0343 - accuracy: 0.4756 - val_loss: 1.0156 - val_accuracy: 0.4766 - 6s/epoch - 323ms/step
# Epoch 92/100
# 20/20 - 6s - loss: 1.0315 - accuracy: 0.4805 - val_loss: 1.0317 - val_accuracy: 0.4844 - 6s/epoch - 315ms/step
# Epoch 93/100
# 20/20 - 6s - loss: 1.0272 - accuracy: 0.4789 - val_loss: 1.0116 - val_accuracy: 0.5156 - 6s/epoch - 309ms/step
# Epoch 94/100
# 20/20 - 5s - loss: 1.0277 - accuracy: 0.4659 - val_loss: 1.0249 - val_accuracy: 0.4922 - 5s/epoch - 256ms/step
# Epoch 95/100
# 20/20 - 6s - loss: 1.0398 - accuracy: 0.4481 - val_loss: 1.0212 - val_accuracy: 0.4531 - 6s/epoch - 277ms/step
# Epoch 96/100
# 20/20 - 5s - loss: 1.0406 - accuracy: 0.4789 - val_loss: 1.0275 - val_accuracy: 0.4453 - 5s/epoch - 243ms/step
# Epoch 97/100
# 20/20 - 5s - loss: 1.0015 - accuracy: 0.5260 - val_loss: 1.0052 - val_accuracy: 0.4922 - 5s/epoch - 252ms/step
# Epoch 98/100
# 20/20 - 5s - loss: 1.0175 - accuracy: 0.4870 - val_loss: 1.0184 - val_accuracy: 0.4844 - 5s/epoch - 262ms/step
# Epoch 99/100
# 20/20 - 5s - loss: 1.0211 - accuracy: 0.4692 - val_loss: 1.0000 - val_accuracy: 0.4922 - 5s/epoch - 245ms/step
# Epoch 100/100
# 20/20 - 5s - loss: 1.0284 - accuracy: 0.4692 - val_loss: 1.0116 - val_accuracy: 0.5234 - 5s/epoch - 244ms/step

# %%
#Plotting the results of the third model
acc3      = history3.history[     'accuracy' ]
val_acc3  = history3.history[ 'val_accuracy' ]
loss3     = history3.history[    'loss' ]
val_loss3 = history3.history['val_loss' ]

epochs3   = range(len(acc3)) # Get number of epochs

#------------------------------------------------
# Plot training and validation accuracy per epoch
#------------------------------------------------
plt.plot  ( epochs3,     acc3, label='Training')
plt.plot  ( epochs3, val_acc3, label='Validation')
plt.title ('Training and validation accuracy')
plt.legend()
plt.figure()

#------------------------------------------------
# Plot training and validation loss per epoch
#------------------------------------------------
plt.plot  ( epochs3,     loss3, label='Training')
plt.plot  ( epochs3, val_loss3, label='Validation')
plt.legend()
plt.title ('Training and validation loss')
# Out:
# Text(0.5, 1.0, 'Training and validation loss')

# %% [markdown]
# # **Comparation**

# %%
#------------------------------------------------
# Plot training accuracy per epoch
#------------------------------------------------
plt.plot  ( epochs2,     acc2, label='Model A')
plt.plot  ( epochs3,     acc3, label='Model B')
plt.plot  ( epochs,      acc,  label='Model C')
plt.title ('Training Accuracy Comparison of The Three Models')
plt.legend()
plt.figure()

#------------------------------------------------
# Plot validation accuracy per epoch
#------------------------------------------------
plt.plot  ( epochs2,     val_acc2, label='Model A')
plt.plot  ( epochs3,     val_acc3, label='Model B')
plt.plot  ( epochs,      val_acc,  label='Model C')
plt.title ('Validation Accuracy Comparison of The Three Models')
plt.legend()
plt.figure()

#------------------------------------------------
# Plot training loss per epoch
#------------------------------------------------
plt.plot  ( epochs2,     loss2, label='Model A')
plt.plot  ( epochs3,     loss3, label='Model B')
plt.plot  ( epochs,      loss,  label='Model C')
plt.title ('Training Loss Comparison of The Three Models')
plt.legend()
plt.figure()

#------------------------------------------------
# Plot validation loss per epoch
#------------------------------------------------
plt.plot  ( epochs2,     val_loss2, label='Model A')
plt.plot  ( epochs3,     val_loss3, label='Model B')
plt.plot  ( epochs,      val_loss,  label='Model C')
plt.title ('Validation Loss Comparison of The Three Models')
plt.legend()
plt.figure()

# %% [markdown]
# # **Save the the Models**

# %%
model.save("Model/Model RSUP/model_C.h5")
model2.save("Model/Model RSUP/model_A.h5")
model3.save("Model/Model RSUP/model_B.h5")
